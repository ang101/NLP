# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import spacy
import spacy.displacy as displacy

# %%
nlp= spacy.load('en_core_web_sm')

# %% [markdown]
# ### spaCy’s Processing Pipeline

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# ### Tokenization:
# Word tokens are the basic units of text involved in any NLPlabeling task. The first step, when processing text, is to split it into tokens.

# %%
doc = nlp('Entrepreneur and business magnate, Elon Musk is the CEO and founder of the aerospace company SpaceX and co-founder of Tesla Motors. He also hopes to change the world, advancing private spaceflight with the aim of landing humans on other planets like Mars, and developing a new tube-transport system called the Hyperloop. Live Science will keep you up on Musk’s latest ideas and developments so you can keep your two feet on Earth while looking up at the stars.')

# %%
token = [token.text for token in doc]
print(token)
# Out:
# ['Entrepreneur', 'and', 'business', 'magnate', ',', 'Elon', 'Musk', 'is', 'the', 'CEO', 'and', 'founder', 'of', 'the', 'aerospace', 'company', 'SpaceX', 'and', 'co', '-', 'founder', 'of', 'Tesla', 'Motors', '.', 'He', 'also', 'hopes', 'to', 'change', 'the', 'world', ',', 'advancing', 'private', 'spaceflight', 'with', 'the', 'aim', 'of', 'landing', 'humans', 'on', 'other', 'planets', 'like', 'Mars', ',', 'and', 'developing', 'a', 'new', 'tube', '-', 'transport', 'system', 'called', 'the', 'Hyperloop', '.', 'Live', 'Science', 'will', 'keep', 'you', 'up', 'on', 'Musk', '’s', 'latest', 'ideas', 'and', 'developments', 'so', 'you', 'can', 'keep', 'your', 'two', 'feet', 'on', 'Earth', 'while', 'looking', 'up', 'at', 'the', 'stars', '.']

# %% [markdown]
# ### **Sentence Detection**

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Entrepreneur and business magnate, Elon Musk is the CEO and founder of the aerospace company SpaceX and co-founder of Tesla Motors.
# He also hopes to change the world, advancing private spaceflight with the aim of landing humans on other planets like Mars, and developing a new tube-transport system called the Hyperloop.
# Live Science will keep you up on Musk’s latest ideas and developments so you can keep your two feet on Earth while looking up at the stars.

# %% [markdown]
# ### Stop Words
# Stop words are the most common words in a language. In the English language, some examples of stop words are the, are, but, and they. Most sentences need to contain stop words in order to be full sentences that make sense.

# %%
all_stop_words = nlp.Defaults.stop_words
print(len(all_stop_words))
print(all_stop_words)
# Out:
# 326
# {'along', 'among', 'thereafter', 'until', 'get', 'since', 'must', 'sometime', 'perhaps', 'wherein', 'being', 're', 'been', 'about', 'much', 'something', 'least', 'doing', 'through', 'what', 'formerly', 'whence', 'see', 'whom', 'against', 'between', 'this', 'whereby', '’ve', 'therefore', 'indeed', 'in', 'ca', 'with', 'because', 'always', "'ll", 'three', 'well', 'hereupon', 'back', 'of', 'together', 'besides', 'eight', 'ten', 'around', 'herein', 'otherwise', 'more', 'last', 'third', 'myself', 'moreover', 'somehow', 'its', 'make', 'mine', 'five', 'keep', 'neither', 'anyone', 'be', 'if', "n't", 'why', 'elsewhere', 'his', 'when', 'these', '’d', 'such', 'each', 'whereafter', 'ours', 'are', 'none', 'has', 'top', 'their', 'same', 'whoever', 'except', 'take', 'thence', 'per', 'thereby', 'other', 'you', 'him', 'did', 'upon', 'should', 'n’t', 'thru', 'her', 'put', 'most', 'may', 'nobody', 'itself', 'hers', 'alone', 'himself', 'themselves', 'does', 'either', 'but', 'above', 'our', '’s', 'had', 'at', 'also', 'within', 'therein', 'that', '‘ve', 'yourselves', 'regarding', 'already', 'there', 'ourselves', 'namely', 'become', 'it', 'as', 'became', 'though', 'say', 'former', 'show', 'he', 'again', 'twelve', 'one', 'would', 'how', 'so', 'mostly', 'can', 'full', 'then', 'once', 'anywhere', 'whether', 'almost', '‘s', 'wherever', 'seem', '‘re', 'various', '‘ll', 'those', 'am', 'seeming', 'twenty', 'anyway', 'side', 'due', 'afterwards', 'anyhow', 'else', 'further', 'two', 'any', 'not', "'s", 'without', 'becoming', 'first', 'thereupon', 'for', 'by', 'serious', 'done', 'were', 'which', 'my', 'or', 'less', 'cannot', 'toward', 'too', 'although', 'nowhere', 'everything', 'forty', 'i', 'thus', 'becomes', 'four', 'quite', 'your', 'hundred', 'others', 'and', 'than', 'below', 'hence', 'a', 'even', 'whole', 'latterly', 'could', 'many', "'d", 'made', 'enough', 'often', 'an', 'please', 'here', 'n‘t', 'name', 'onto', 'only', 'have', '‘d', 'everyone', 'latter', "'re", 'might', "'m", 'six', 'towards', 'beyond', 'few', 'go', 'into', 'on', 'all', 'before', 'hereby', 'do', 'own', 'call', 'eleven', 'after', 'whenever', 'everywhere', 'meanwhile', 'move', 'fifty', 'over', 'hereafter', 'to', 'where', 'they', 'across', 'whereas', 'whose', 'via', 'off', 'ever', 'whereupon', 'from', 'no', 'us', 'nor', 'noone', '‘m', 'really', 'every', 'behind', 'using', 'whatever', 'while', 'very', 'them', 'nevertheless', 'under', 'anything', 'herself', 'fifteen', 'front', 'nine', 'give', 'next', 'beforehand', 'me', 'amongst', 'sixty', 'several', 'used', 'just', 'up', 'during', 'down', 'some', 'another', 'we', 'yourself', 'rather', 'the', 'seemed', 'sometimes', 'somewhere', 'unless', 'who', '’ll', '’re', 'still', 'beside', 'whither', 'now', 'part', 'throughout', 'nothing', 'empty', 'amount', 'never', 'seems', 'out', 'will', 'however', 'was', 'she', 'both', 'bottom', 'yet', '’m', 'is', 'someone', "'ve", 'yours'}

# %%
tokenized_words = [word.text for word in doc]
print(tokenized_words)
# Out:
# ['Entrepreneur', 'and', 'business', 'magnate', ',', 'Elon', 'Musk', 'is', 'the', 'CEO', 'and', 'founder', 'of', 'the', 'aerospace', 'company', 'SpaceX', 'and', 'co', '-', 'founder', 'of', 'Tesla', 'Motors', '.', 'He', 'also', 'hopes', 'to', 'change', 'the', 'world', ',', 'advancing', 'private', 'spaceflight', 'with', 'the', 'aim', 'of', 'landing', 'humans', 'on', 'other', 'planets', 'like', 'Mars', ',', 'and', 'developing', 'a', 'new', 'tube', '-', 'transport', 'system', 'called', 'the', 'Hyperloop', '.', 'Live', 'Science', 'will', 'keep', 'you', 'up', 'on', 'Musk', '’s', 'latest', 'ideas', 'and', 'developments', 'so', 'you', 'can', 'keep', 'your', 'two', 'feet', 'on', 'Earth', 'while', 'looking', 'up', 'at', 'the', 'stars', '.']

# %%
removed_stop_words = [word for word in tokenized_words if word not in all_stop_words]
print(removed_stop_words)
# Out:
# ['Entrepreneur', 'business', 'magnate', ',', 'Elon', 'Musk', 'CEO', 'founder', 'aerospace', 'company', 'SpaceX', 'co', '-', 'founder', 'Tesla', 'Motors', '.', 'He', 'hopes', 'change', 'world', ',', 'advancing', 'private', 'spaceflight', 'aim', 'landing', 'humans', 'planets', 'like', 'Mars', ',', 'developing', 'new', 'tube', '-', 'transport', 'system', 'called', 'Hyperloop', '.', 'Live', 'Science', 'Musk', 'latest', 'ideas', 'developments', 'feet', 'Earth', 'looking', 'stars', '.']

# %% [markdown]
# ### Lemmatization

# %%
for word in doc:
    if not word.is_stop and not word.is_punct:
        print(word.text,"|",word.lemma_)
# Out:
# Entrepreneur | Entrepreneur
# business | business
# magnate | magnate
# Elon | Elon
# Musk | Musk
# CEO | ceo
# founder | founder
# aerospace | aerospace
# company | company
# SpaceX | SpaceX
# co | co
# founder | founder
# Tesla | Tesla
# Motors | Motors
# hopes | hope
# change | change
# world | world
# advancing | advance
# private | private
# spaceflight | spaceflight
# aim | aim
# landing | land
# humans | human
# planets | planet
# like | like
# Mars | Mars
# developing | develop
# new | new
# tube | tube
# transport | transport
# system | system
# called | call
# Hyperloop | Hyperloop
# Live | Live
# Science | Science
# Musk | Musk
# latest | late
# ideas | idea
# developments | development
# feet | foot
# Earth | Earth
# looking | look
# stars | star

# %% [markdown]
# ### Word Frequency

# %%
import string
punctuation = string.punctuation
print(punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
words = list(doc)
wordList = [word.lemma_ for word in words if not word.is_stop and not word.is_punct ]
print(wordList)
# Out:
# ['Entrepreneur', 'business', 'magnate', 'Elon', 'Musk', 'ceo', 'founder', 'aerospace', 'company', 'SpaceX', 'co', 'founder', 'Tesla', 'Motors', 'hope', 'change', 'world', 'advance', 'private', 'spaceflight', 'aim', 'land', 'human', 'planet', 'like', 'Mars', 'develop', 'new', 'tube', 'transport', 'system', 'call', 'Hyperloop', 'Live', 'Science', 'Musk', 'late', 'idea', 'development', 'foot', 'Earth', 'look', 'star']

# %%
from collections import Counter
listOfWords = Counter(wordList)
print(listOfWords)
# Out:
# Counter({'Musk': 2, 'founder': 2, 'Entrepreneur': 1, 'business': 1, 'magnate': 1, 'Elon': 1, 'ceo': 1, 'aerospace': 1, 'company': 1, 'SpaceX': 1, 'co': 1, 'Tesla': 1, 'Motors': 1, 'hope': 1, 'change': 1, 'world': 1, 'advance': 1, 'private': 1, 'spaceflight': 1, 'aim': 1, 'land': 1, 'human': 1, 'planet': 1, 'like': 1, 'Mars': 1, 'develop': 1, 'new': 1, 'tube': 1, 'transport': 1, 'system': 1, 'call': 1, 'Hyperloop': 1, 'Live': 1, 'Science': 1, 'late': 1, 'idea': 1, 'development': 1, 'foot': 1, 'Earth': 1, 'look': 1, 'star': 1})

# %%
print(listOfWords.most_common(5))
# Out:
# [('Musk', 2), ('founder', 2), ('Entrepreneur', 1), ('business', 1), ('magnate', 1)]

# %% [markdown]
# ### Part of Speech Tagging
# Part of speech or POS is a grammatical role that explains how a particular word is used in a sentence

# %%
for word in doc:
    print(word.text,'|',word.tag_,'|',spacy.explain(word.tag_))
# Out:
# Entrepreneur | NNP | noun, proper singular
# and | CC | conjunction, coordinating
# business | NN | noun, singular or mass
# magnate | NN | noun, singular or mass
# , | , | punctuation mark, comma
# Elon | NNP | noun, proper singular
# Musk | NNP | noun, proper singular
# is | VBZ | verb, 3rd person singular present
# the | DT | determiner
# CEO | NN | noun, singular or mass
# and | CC | conjunction, coordinating
# founder | NN | noun, singular or mass
# of | IN | conjunction, subordinating or preposition
# the | DT | determiner
# aerospace | NN | noun, singular or mass
# company | NN | noun, singular or mass
# SpaceX | '' | closing quotation mark
# and | CC | conjunction, coordinating
# co | NN | noun, singular or mass
# - | NN | noun, singular or mass
# founder | NN | noun, singular or mass
# of | IN | conjunction, subordinating or preposition
# Tesla | NNP | noun, proper singular
# Motors | NNPS | noun, proper plural
# . | . | punctuation mark, sentence closer
# He | PRP | pronoun, personal
# also | RB | adverb
# hopes | VBZ | verb, 3rd person singular present
# to | TO | infinitival "to"
# change | VB | verb, base form
# the | DT | determiner
# world | NN | noun, singular or mass
# , | , | punctuation mark, comma
# advancing | VBG | verb, gerund or present participle
# private | JJ | adjective (English), other noun-modifier (Chinese)
# spaceflight | NN | noun, singular or mass
# with | IN | conjunction, subordinating or preposition
# the | DT | determiner
# aim | NN | noun, singular or mass
# of | IN | conjunction, subordinating or preposition
# landing | VBG | verb, gerund or present participle
# humans | NNS | noun, plural
# on | IN | conjunction, subordinating or preposition
# other | JJ | adjective (English), other noun-modifier (Chinese)
# planets | NNS | noun, plural
# like | IN | conjunction, subordinating or preposition
# Mars | NNP | noun, proper singular
# , | , | punctuation mark, comma
# and | CC | conjunction, coordinating
# developing | VBG | verb, gerund or present participle
# a | DT | determiner
# new | JJ | adjective (English), other noun-modifier (Chinese)
# tube | NN | noun, singular or mass
# - | HYPH | punctuation mark, hyphen
# transport | NN | noun, singular or mass
# system | NN | noun, singular or mass
# called | VBD | verb, past tense
# the | DT | determiner
# Hyperloop | NNP | noun, proper singular
# . | . | punctuation mark, sentence closer
# Live | NNP | noun, proper singular
# Science | NNP | noun, proper singular
# will | MD | verb, modal auxiliary
# keep | VB | verb, base form
# you | PRP | pronoun, personal
# up | RP | adverb, particle
# on | IN | conjunction, subordinating or preposition
# Musk | NNP | noun, proper singular
# ’s | POS | possessive ending
# latest | JJS | adjective, superlative
# ideas | NNS | noun, plural
# and | CC | conjunction, coordinating
# developments | NNS | noun, plural
# so | IN | conjunction, subordinating or preposition
# you | PRP | pronoun, personal
# can | MD | verb, modal auxiliary
# keep | VB | verb, base form
# your | PRP$ | pronoun, possessive
# two | CD | cardinal number
# feet | NNS | noun, plural
# on | IN | conjunction, subordinating or preposition
# Earth | NNP | noun, proper singular
# while | IN | conjunction, subordinating or preposition
# looking | VBG | verb, gerund or present participle
# up | RP | adverb, particle
# at | IN | conjunction, subordinating or preposition
# the | DT | determiner
# stars | NNS | noun, plural
# . | . | punctuation mark, sentence closer

# %% [markdown]
# ### Dependency Parsing using spaCy
# Every sentence has a grammatical structure to it and with the help of dependency parsing, we can extract this structure.

# %%
for word in doc:
    print(word.text,'|',word.dep_)
# Out:
# Entrepreneur | nmod
# and | cc
# business | conj
# magnate | nsubj
# , | punct
# Elon | compound
# Musk | nsubj
# is | ROOT
# the | det
# CEO | attr
# and | cc
# founder | conj
# of | prep
# the | det
# aerospace | compound
# company | pobj
# SpaceX | punct
# and | cc
# co | conj
# - | conj
# founder | appos
# of | prep
# Tesla | compound
# Motors | pobj
# . | punct
# He | nsubj
# also | advmod
# hopes | ROOT
# to | aux
# change | xcomp
# the | det
# world | dobj
# , | punct
# advancing | advcl
# private | amod
# spaceflight | dobj
# with | prep
# the | det
# aim | pobj
# of | prep
# landing | pcomp
# humans | dobj
# on | prep
# other | amod
# planets | pobj
# like | prep
# Mars | pobj
# , | punct
# and | cc
# developing | conj
# a | det
# new | amod
# tube | compound
# - | punct
# transport | compound
# system | dobj
# called | acl
# the | det
# Hyperloop | oprd
# . | punct
# Live | intj
# Science | nsubj
# will | aux
# keep | ROOT
# you | dobj
# up | prt
# on | prep
# Musk | poss
# ’s | case
# latest | amod
# ideas | pobj
# and | cc
# developments | conj
# so | mark
# you | nsubj
# can | aux
# keep | advcl
# your | poss
# two | nummod
# feet | dobj
# on | prep
# Earth | pobj
# while | mark
# looking | advcl
# up | prt
# at | prep
# the | det
# stars | pobj
# . | punct

# %%
displacy.serve(doc,style='dep')
# Out:
# /opt/conda/lib/python3.7/site-packages/spacy/displacy/__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="19dae29fe55f48868aa129bbf0b84e9b-0" class="displacy" width="14225" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Entrepreneur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">business</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">magnate,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Elon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Musk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">CEO</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">founder</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">aerospace</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">SpaceX</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">co-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">founder</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Tesla</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Motors.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">hopes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">change</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">world,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-w
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ### Named Entity Recognition using spaCy
# Entities are the words or groups of words that represent information about common things such as persons, locations, organizations, etc.

# %%
for word in doc.ents:
    print(word.text,"|",word.label_)
# Out:
# Elon Musk | PERSON
# Tesla Motors | ORG
# Mars | LOC
# Hyperloop | ORG
# Musk | PERSON
# two feet | QUANTITY
# Earth | LOC

# %%
displacy.serve(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Entrepreneur and business magnate,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the CEO and founder of the aerospace company SpaceX and co-founder of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Motors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . He also hopes to change the world, advancing private spaceflight with the aim of landing humans on other planets like
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , and developing a new tube-transport system called the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hyperloop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Live Science will keep you up on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s latest ideas and developments so you can keep your
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  while looking up at the stars.</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
for word in doc:
    pass
#     print(word.i,word.text)
    
from spacy.tokens import Span
s1 = Span(doc,16,17,label='ORG')
doc.set_ents([s1],default='unmodified')

# %%
displacy.serve(doc,style='ent')
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">Entrepreneur and business magnate,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Elon Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the CEO and founder of the aerospace company
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SpaceX
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and co-founder of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Motors
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . He also hopes to change the world, advancing private spaceflight with the aim of landing humans on other planets like
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mars
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , and developing a new tube-transport system called the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hyperloop
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . Live Science will keep you up on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Musk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s latest ideas and developments so you can keep your
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two feet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  on
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  while looking up at the stars.</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ### Document similarities

# %%
text1 = nlp('hello ,I am vishvanath')
text2 = nlp('how are you')
print("similarity",text1.similarity(text2))
# Out:
# similarity 0.5655234729474474
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   This is separate from the ipykernel package so we can avoid doing imports until
